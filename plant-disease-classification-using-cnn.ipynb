# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import datasets, transforms

# %%
dataset_path = "/kaggle/input/datasets/pantho12/sar-cld-2024-dataset-for-cotton-leaf/SAR-CLD-2024 A Comprehensive Dataset for Cotton Leaf Disease Detection/Original Dataset/Original Dataset"
print(os.listdir(dataset_path))
# Out:
# ['Curl Virus', 'Healthy Leaf', 'Leaf Hopper Jassids', 'Leaf Variegation', 'Leaf Redding', 'Bacterial Blight', 'Herbicide Growth Damage']

# %%
class MyDataSet(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform

        # Get class names
        self.classes = sorted(os.listdir(root_dir))

        # Map class name -> integer label
        self.class_to_idx = {
            cls_name: idx
            for idx, cls_name in enumerate(self.classes)
        }

        # Store (image_path, label) pairs
        self.samples = []
        for class_name in self.classes:
            class_folder = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_folder):
                image_path = os.path.join(class_folder, image_name)
                label = self.class_to_idx[class_name]
                self.samples.append((image_path, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, i):
        image_path, label = self.samples[i]
        image = Image.open(image_path).convert("RGB")
        image = self.transform(image)
        return image, label

# %%
no_transform = transforms.Compose([
                    transforms.Resize((128,128)),
                    transforms.ToTensor()
                ])
myds = MyDataSet(dataset_path,no_transform)
print(len(myds))
tds_size = int(0.8*len(myds))
vds_size = len(myds)-tds_size
print(tds_size)
print(vds_size)

tds,vds = random_split(myds,[tds_size,vds_size])


tdl = DataLoader(tds,batch_size=32,shuffle=True)
vdl = DataLoader(vds,batch_size=32,shuffle=True)
# Out:
# 2137
# 1709
# 428

# %%
img , lbl = myds[1600]
timg, tlbl = tds[1600]
vimg, vlbl = vds[400]

fig, ax = plt.subplots(1, 3, figsize=(12,4))

ax[0].imshow(img.permute(1,2,0))
ax[0].set_title(lbl)

ax[1].imshow(timg.permute(1,2,0))
ax[1].set_title(tlbl)

ax[2].imshow(vimg.permute(1,2,0))
ax[2].set_title(vlbl)
# Out:
# Text(0.5, 1.0, '3')

# %%
class myModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv1 = nn.Conv2d(3,16,kernel_size=3,padding=1)
    self.conv2 = nn.Conv2d(16,32,kernel_size=3,padding=1)
    self.conv3 = nn.Conv2d(32,64,kernel_size=3,padding=1)
    self.pool = nn.MaxPool2d(2)
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    self.fc1 = nn.Linear(64*16*16, 128)
    self.fc2 = nn.Linear(128, 7)

  def forward(self,x):
    x = self.pool(self.relu(self.conv1(x)))
    x = self.pool(self.relu(self.conv2(x)))
    x = self.pool(self.relu(self.conv3(x)))
    x = self.flatten(x)
    x = self.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = myModel().to(device)
print(device)
# Out:
# cuda

# %%
def train(model, train_ld, val_ld, epochs, lr=0.0001):
    loss_func = nn.CrossEntropyLoss()
    opt = optim.Adam(model.parameters(), lr=lr)

    history = {"train_loss": [],"val_loss": [],"train_acc": [],"val_acc": []}

    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        for img, lbl in train_ld:
            img, lbl = img.to(device), lbl.to(device)

            opt.zero_grad()
            prediction = model(img)
            loss = loss_func(prediction, lbl)
            loss.backward()
            opt.step()

            running_loss += loss.item() * img.size(0)
            correct += (prediction.argmax(1) == lbl).sum().item()
            total += lbl.size(0)

        train_loss = running_loss / total
        train_acc = correct / total

        model.eval()
        running_loss, correct, total = 0.0, 0, 0

        with torch.no_grad():
            for imgs, labels in val_ld:
                imgs, labels = imgs.to(device), labels.to(device)

                outputs = model(imgs)
                loss = loss_func(outputs, labels)

                running_loss += loss.item() * imgs.size(0)
                correct += (outputs.argmax(1) == labels).sum().item()
                total += labels.size(0)

        val_loss = running_loss / total
        val_acc = correct / total

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        print(
            f"Epoch {epoch+1:2d}/{epochs} | "
            f"train_loss={train_loss:.3f} train_acc={train_acc:.3f} | "
            f"val_loss={val_loss:.3f} val_acc={val_acc:.3f}"
        )

    return history

# %%
history_plain = train(model, tdl, vdl, epochs=50)
# Out:
# Epoch  1/50 | train_loss=1.856 train_acc=0.263 | val_loss=1.850 val_acc=0.269
# Epoch  2/50 | train_loss=1.762 train_acc=0.321 | val_loss=1.708 val_acc=0.343
# Epoch  3/50 | train_loss=1.556 train_acc=0.403 | val_loss=1.509 val_acc=0.414
# Epoch  4/50 | train_loss=1.386 train_acc=0.463 | val_loss=1.431 val_acc=0.432
# Epoch  5/50 | train_loss=1.280 train_acc=0.487 | val_loss=1.330 val_acc=0.467
# Epoch  6/50 | train_loss=1.200 train_acc=0.523 | val_loss=1.267 val_acc=0.516
# Epoch  7/50 | train_loss=1.152 train_acc=0.551 | val_loss=1.218 val_acc=0.537
# Epoch  8/50 | train_loss=1.093 train_acc=0.590 | val_loss=1.199 val_acc=0.568
# Epoch  9/50 | train_loss=1.052 train_acc=0.602 | val_loss=1.139 val_acc=0.558
# Epoch 10/50 | train_loss=1.005 train_acc=0.617 | val_loss=1.123 val_acc=0.582
# Epoch 11/50 | train_loss=0.971 train_acc=0.637 | val_loss=1.084 val_acc=0.591
# Epoch 12/50 | train_loss=0.931 train_acc=0.651 | val_loss=1.066 val_acc=0.591
# Epoch 13/50 | train_loss=0.898 train_acc=0.665 | val_loss=1.047 val_acc=0.617
# Epoch 14/50 | train_loss=0.880 train_acc=0.658 | val_loss=1.038 val_acc=0.610
# Epoch 15/50 | train_loss=0.834 train_acc=0.690 | val_loss=1.044 val_acc=0.612
# Epoch 16/50 | train_loss=0.828 train_acc=0.688 | val_loss=0.995 val_acc=0.638
# Epoch 17/50 | train_loss=0.791 train_acc=0.695 | val_loss=1.035 val_acc=0.614
# Epoch 18/50 | train_loss=0.764 train_acc=0.714 | val_loss=1.016 val_acc=0.617
# Epoch 19/50 | train_loss=0.746 train_acc=0.726 | val_loss=0.984 val_acc=0.636
# Epoch 20/50 | train_loss=0.709 train_acc=0.731 | val_loss=0.987 val_acc=0.636
# Epoch 21/50 | train_loss=0.719 train_acc=0.724 | val_loss=0.979 val_acc=0.619
# Epoch 22/50 | train_loss=0.683 train_acc=0.743 | val_loss=0.956 val_acc=0.638
# Epoch 23/50 | train_loss=0.645 train_acc=0.755 | val_loss=0.939 val_acc=0.647
# Epoch 24/50 | train_loss=0.636 train_acc=0.763 | val_loss=0.956 val_acc=0.624
# Epoch 25/50 | train_loss=0.611 train_acc=0.778 | val_loss=0.924 val_acc=0.661
# Epoch 26/50 | train_loss=0.587 train_acc=0.789 | val_loss=0.958 val_acc=0.678
# Epoch 27/50 | train_loss=0.580 train_acc=0.793 | val_loss=1.013 val_acc=0.621
# Epoch 28/50 | train_loss=0.565 train_acc=0.792 | val_loss=0.958 val_acc=0.629
# Epoch 29/50 | train_loss=0.542 train_acc=0.805 | val_loss=0.946 val_acc=0.664
# Epoch 30/50 | train_loss=0.517 train_acc=0.819 | val_loss=0.951 val_acc=0.652
# Epoch 31/50 | train_loss=0.498 train_acc=0.825 | val_loss=0.930 val_acc=0.657
# Epoch 32/50 | train_loss=0.490 train_acc=0.834 | val_loss=0.939 val_acc=0.659
# Epoch 33/50 | train_loss=0.475 train_acc=0.830 | val_loss=0.904 val_acc=0.671
# Epoch 34/50 | train_loss=0.463 train_acc=0.841 | val_loss=0.924 val_acc=0.664
# Epoch 35/50 | train_loss=0.448 train_acc=0.853 | val_loss=0.971 val_acc=0.629
# Epoch 36/50 | train_loss=0.426 train_acc=0.861 | val_loss=0.919 val_acc=0.685
# Epoch 37/50 | train_loss=0.399 train_acc=0.869 | val_loss=0.920 val_acc=0.661
# Epoch 38/50 | train_loss=0.406 train_acc=0.858 | val_loss=0.942 val_acc=0.666
# Epoch 39/50 | train_loss=0.385 train_acc=0.871 | val_loss=0.925 val_acc=0.673
# Epoch 40/50 | train_loss=0.365 train_acc=0.883 | val_loss=0.913 val_acc=0.682
# Epoch 41/50 | train_loss=0.352 train_acc=0.879 | val_loss=1.038 val_acc=0.657
# Epoch 42/50 | train_loss=0.350 train_acc=0.887 | val_loss=0.920 val_acc=0.687
# Epoch 43/50 | train_loss=0.345 train_acc=0.896 | val_loss=0.961 val_acc=0.661
# Epoch 44/50 | train_loss=0.315 train_acc=0.896 | val_loss=0.949 val_acc=0.657
# Epoch 45/50 | train_loss=0.320 train_acc=0.898 | val_loss=0.934 val_acc=0.685
# Epoch 46/50 | train_loss=0.299 train_acc=0.912 | val_loss=1.024 val_acc=0.668
# Epoch 47/50 | train_loss=0.280 train_acc=0.916 | val_loss=0.962 val_acc=0.671
# Epoch 48/50 | train_loss=0.265 train_acc=0.923 | val_loss=1.048 val_acc=0.659
# Epoch 49/50 | train_loss=0.277 train_acc=0.923 | val_loss=1.085 val_acc=0.657
# Epoch 50/50 | train_loss=0.252 train_acc=0.926 | val_loss=0.973 val_acc=0.675

# %%
def plot_history(history, title=""):
    epochs = range(1, len(history["train_loss"]) + 1)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    ax1.plot(epochs, history["train_loss"], "o-", label="train")
    ax1.plot(epochs, history["val_loss"],   "o-", label="validation")
    ax1.set_title("Loss (lower = better)")
    ax1.set_xlabel("epoch"); ax1.set_ylabel("loss"); ax1.legend(); ax1.grid(True)

    ax2.plot(epochs, history["train_acc"], "o-", label="train")
    ax2.plot(epochs, history["val_acc"],   "o-", label="validation")
    ax2.set_title("Accuracy (higher = better)")
    ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy"); ax2.legend(); ax2.grid(True)

    fig.suptitle(title)
    plt.tight_layout()
    plt.show()

plot_history(history_plain, "Without augmentation")

# %%
from torch.utils.data import random_split, Subset

normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)

train_transform = transforms.Compose([
    # slightly larger resize
    transforms.Resize((160, 160)),

    # random crop for better generalization
    transforms.RandomResizedCrop(
        128,
        scale=(0.80, 1.0),
        ratio=(0.90, 1.10)
    ),

    # natural orientation changes
    transforms.RandomHorizontalFlip(p=0.5),

    # small rotation only
    transforms.RandomRotation(8),

    # mild lighting variation
    transforms.ColorJitter(
        brightness=0.10,
        contrast=0.10,
        saturation=0.08,
        hue=0.015
    ),

    # occasional blur
    transforms.RandomApply([
        transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 1.0))
    ], p=0.08),

    transforms.ToTensor(),
    normalize,

    # helps reduce overfitting
    transforms.RandomErasing(
        p=0.20,
        scale=(0.02, 0.06),
        ratio=(0.3, 3.3),
        value='random'
    )
])

val_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),normalize
])

train_dataset = MyDataSet(dataset_path, train_transform)
val_dataset = MyDataSet(dataset_path, val_transform)

dataset_size = len(train_dataset)

train_size = int(0.8 * dataset_size)
val_size = dataset_size - train_size

train_subset, val_subset = random_split(
    range(dataset_size),
    [train_size, val_size]
)

_tds = Subset(train_dataset, train_subset.indices)
_vds = Subset(val_dataset, val_subset.indices)

_tdl = DataLoader(_tds, batch_size=32, shuffle=True)
_vdl = DataLoader(_vds, batch_size=32, shuffle=False)

# %%
img , lbl = myds[1600]
timg, tlbl = _tds[1600]
vimg, vlbl = _vds[400]

fig, ax = plt.subplots(1, 3, figsize=(12,4))

ax[0].imshow(img.permute(1,2,0))
ax[0].set_title(lbl)

ax[1].imshow(timg.permute(1,2,0))
ax[1].set_title(tlbl)

ax[2].imshow(vimg.permute(1,2,0))
ax[2].set_title(vlbl)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.4831376].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9637812..2.5528543].
# Text(0.5, 1.0, '2')

# %%
_model = myModel().to(device)

_history = train(_model,_tdl,_vdl,epochs=50)
plot_history(_history,"With augmentation")
# Out:
# Epoch  1/50 | train_loss=1.776 train_acc=0.313 | val_loss=1.620 val_acc=0.362
# Epoch  2/50 | train_loss=1.529 train_acc=0.383 | val_loss=1.420 val_acc=0.430
# Epoch  3/50 | train_loss=1.304 train_acc=0.504 | val_loss=1.333 val_acc=0.465
# Epoch  4/50 | train_loss=1.176 train_acc=0.527 | val_loss=1.102 val_acc=0.577
# Epoch  5/50 | train_loss=1.066 train_acc=0.599 | val_loss=1.002 val_acc=0.631
# Epoch  6/50 | train_loss=1.007 train_acc=0.611 | val_loss=0.952 val_acc=0.636
# Epoch  7/50 | train_loss=0.940 train_acc=0.625 | val_loss=0.948 val_acc=0.633
# Epoch  8/50 | train_loss=0.905 train_acc=0.646 | val_loss=0.943 val_acc=0.617
# Epoch  9/50 | train_loss=0.910 train_acc=0.656 | val_loss=1.067 val_acc=0.586
# Epoch 10/50 | train_loss=0.849 train_acc=0.670 | val_loss=0.864 val_acc=0.666
# Epoch 11/50 | train_loss=0.832 train_acc=0.669 | val_loss=0.888 val_acc=0.654
# Epoch 12/50 | train_loss=0.818 train_acc=0.679 | val_loss=0.846 val_acc=0.678
# Epoch 13/50 | train_loss=0.798 train_acc=0.689 | val_loss=0.921 val_acc=0.661
# Epoch 14/50 | train_loss=0.762 train_acc=0.720 | val_loss=0.827 val_acc=0.673
# Epoch 15/50 | train_loss=0.737 train_acc=0.720 | val_loss=0.819 val_acc=0.689
# Epoch 16/50 | train_loss=0.739 train_acc=0.709 | val_loss=0.815 val_acc=0.687
# Epoch 17/50 | train_loss=0.717 train_acc=0.719 | val_loss=0.825 val_acc=0.692
# Epoch 18/50 | train_loss=0.696 train_acc=0.741 | val_loss=0.772 val_acc=0.706
# Epoch 19/50 | train_loss=0.679 train_acc=0.746 | val_loss=0.759 val_acc=0.701
# Epoch 20/50 | train_loss=0.673 train_acc=0.744 | val_loss=0.765 val_acc=0.713
# Epoch 21/50 | train_loss=0.653 train_acc=0.760 | val_loss=0.787 val_acc=0.703
# Epoch 22/50 | train_loss=0.628 train_acc=0.762 | val_loss=0.766 val_acc=0.703
# Epoch 23/50 | train_loss=0.626 train_acc=0.769 | val_loss=0.770 val_acc=0.689
# Epoch 24/50 | train_loss=0.614 train_acc=0.767 | val_loss=0.743 val_acc=0.713
# Epoch 25/50 | train_loss=0.600 train_acc=0.774 | val_loss=0.715 val_acc=0.734
# Epoch 26/50 | train_loss=0.604 train_acc=0.770 | val_loss=0.719 val_acc=0.727
# Epoch 27/50 | train_loss=0.561 train_acc=0.789 | val_loss=0.712 val_acc=0.724
# Epoch 28/50 | train_loss=0.563 train_acc=0.782 | val_loss=0.736 val_acc=0.722
# Epoch 29/50 | train_loss=0.558 train_acc=0.787 | val_loss=0.739 val_acc=0.731
# Epoch 30/50 | train_loss=0.536 train_acc=0.789 | val_loss=0.706 val_acc=0.736
# Epoch 31/50 | train_loss=0.542 train_acc=0.808 | val_loss=0.695 val_acc=0.743
# Epoch 32/50 | train_loss=0.540 train_acc=0.803 | val_loss=0.658 val_acc=0.764
# Epoch 33/50 | train_loss=0.498 train_acc=0.824 | val_loss=0.691 val_acc=0.748
# Epoch 34/50 | train_loss=0.512 train_acc=0.810 | val_loss=0.709 val_acc=0.724
# Epoch 35/50 | train_loss=0.475 train_acc=0.828 | val_loss=0.656 val_acc=0.762
# Epoch 36/50 | train_loss=0.472 train_acc=0.827 | val_loss=0.714 val_acc=0.736
# Epoch 37/50 | train_loss=0.482 train_acc=0.813 | val_loss=0.646 val_acc=0.773
# Epoch 38/50 | train_loss=0.480 train_acc=0.827 | val_loss=0.635 val_acc=0.769
# Epoch 39/50 | train_loss=0.465 train_acc=0.827 | val_loss=0.634 val_acc=0.790
# Epoch 40/50 | train_loss=0.449 train_acc=0.837 | val_loss=0.682 val_acc=0.759
# Epoch 41/50 | train_loss=0.453 train_acc=0.836 | val_loss=0.625 val_acc=0.780
# Epoch 42/50 | train_loss=0.417 train_acc=0.847 | val_loss=0.632 val_acc=0.776
# Epoch 43/50 | train_loss=0.427 train_acc=0.841 | val_loss=0.670 val_acc=0.750
# Epoch 44/50 | train_loss=0.421 train_acc=0.849 | val_loss=0.602 val_acc=0.794
# Epoch 45/50 | train_loss=0.395 train_acc=0.858 | val_loss=0.617 val_acc=0.778
# Epoch 46/50 | train_loss=0.387 train_acc=0.860 | val_loss=0.617 val_acc=0.776
# Epoch 47/50 | train_loss=0.374 train_acc=0.854 | val_loss=0.620 val_acc=0.785
# Epoch 48/50 | train_loss=0.378 train_acc=0.868 | val_loss=0.630 val_acc=0.771
# Epoch 49/50 | train_loss=0.391 train_acc=0.867 | val_loss=0.597 val_acc=0.801
# Epoch 50/50 | train_loss=0.361 train_acc=0.865 | val_loss=0.689 val_acc=0.766

# %%
plt.figure(figsize=(7, 5))
plt.plot(history_plain["val_acc"], "o-", label="Round 1: no augmentation")
plt.plot(_history["val_acc"],   "o-", label="Round 2: augmentation")
plt.title("Validation accuracy — before vs after")
plt.xlabel("epoch"); plt.ylabel("validation accuracy")
plt.legend(); plt.grid(True)
plt.show()

print(f"Best val acc  (Round 1): {max(history_plain['val_acc']):.3f}")
print(f"Best val acc  (Round 2): {max(_history['val_acc']):.3f}")
# Out:
# Best val acc  (Round 1): 0.687
# Best val acc  (Round 2): 0.801

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import torch

# trained without augmentation
model_unaug = model

# trained with augmentation
model_aug = _model

def get_predictions(model, loader):
    model.eval()
    preds = []
    targets = []

    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            labels = labels.to(device)

            outputs = model(imgs)
            preds.extend(outputs.argmax(dim=1).cpu().numpy())
            targets.extend(labels.cpu().numpy())

    return targets, preds


class_names = [
    "Bacterial Blight",
    "Curl Virus",
    "Healthy Leaf",
    "Herbicide Growth Damage",
    "Leaf Hopper Jassids",
    "Leaf Redding",
    "Leaf Variegation"
]

# Predictions
y_true_unaug, y_pred_unaug = get_predictions(model_unaug, _vdl)
y_true_aug, y_pred_aug = get_predictions(model_aug, _vdl)

# Confusion matrices
cm_unaug = confusion_matrix(y_true_unaug, y_pred_unaug)
cm_aug = confusion_matrix(y_true_aug, y_pred_aug)

# Create one figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Unaugmented
disp1 = ConfusionMatrixDisplay(
    confusion_matrix=cm_unaug,
    display_labels=class_names
)
disp1.plot(ax=axes[0], cmap="Blues", values_format="d", colorbar=False)
axes[0].set_title("Without Augmentation")
axes[0].tick_params(axis='x', rotation=45)

# Augmented
disp2 = ConfusionMatrixDisplay(
    confusion_matrix=cm_aug,
    display_labels=class_names
)
disp2.plot(ax=axes[1], cmap="Greens", values_format="d", colorbar=False)
axes[1].set_title("With Augmentation")
axes[1].tick_params(axis='x', rotation=45)

plt.suptitle("Confusion Matrix Comparison", fontsize=16)
plt.tight_layout()
plt.show()

print("===== WITHOUT AUGMENTATION =====")
print(classification_report(y_true_unaug, y_pred_unaug, target_names=class_names))

print("===== WITH AUGMENTATION =====")
print(classification_report(y_true_aug, y_pred_aug, target_names=class_names))
# Out:
# ===== WITHOUT AUGMENTATION =====
#                          precision    recall  f1-score   support
#
#        Bacterial Blight       0.55      0.13      0.21        47
#              Curl Virus       0.40      0.94      0.56        95
#            Healthy Leaf       0.83      0.10      0.18        50
# Herbicide Growth Damage       0.35      0.74      0.48        53
#     Leaf Hopper Jassids       0.89      0.18      0.30        45
#            Leaf Redding       0.90      0.50      0.64       120
#        Leaf Variegation       0.50      0.06      0.10        18
#
#                accuracy                           0.49       428
#               macro avg       0.63      0.38      0.35       428
#            weighted avg       0.66      0.49      0.44       428
#
# ===== WITH AUGMENTATION =====
#                          precision    recall  f1-score   support
#
#        Bacterial Blight       0.55      0.77      0.64        47
#              Curl Virus       0.77      0.89      0.83        95
#            Healthy Leaf       0.81      0.58      0.67        50
# Herbicide Growth Damage       0.85      0.96      0.90        53
#     Leaf Hopper Jassids       0.59      0.44      0.51        45
#            Leaf Redding       0.96      0.76      0.85       120
#        Leaf Variegation       0.59      0.89      0.71        18
#
#                accuracy                           0.77       428
#               macro avg       0.73      0.76      0.73       428
#            weighted avg       0.79      0.77      0.77       428
