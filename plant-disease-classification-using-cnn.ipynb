# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import datasets, transforms

# %%
dataset_path = "/kaggle/input/datasets/pantho12/sar-cld-2024-dataset-for-cotton-leaf/SAR-CLD-2024 A Comprehensive Dataset for Cotton Leaf Disease Detection/Original Dataset/Original Dataset"
print(os.listdir(dataset_path))
# Out:
# ['Curl Virus', 'Healthy Leaf', 'Leaf Hopper Jassids', 'Leaf Variegation', 'Leaf Redding', 'Bacterial Blight', 'Herbicide Growth Damage']

# %%
class MyDataSet(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform

        # Get class names
        self.classes = sorted(os.listdir(root_dir))

        # Map class name -> integer label
        self.class_to_idx = {
            cls_name: idx
            for idx, cls_name in enumerate(self.classes)
        }

        # Store (image_path, label) pairs
        self.samples = []
        for class_name in self.classes:
            class_folder = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_folder):
                image_path = os.path.join(class_folder, image_name)
                label = self.class_to_idx[class_name]
                self.samples.append((image_path, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, i):
        image_path, label = self.samples[i]
        image = Image.open(image_path).convert("RGB")
        image = self.transform(image)
        return image, label

# %%
no_transform = transforms.Compose([
                    transforms.Resize((128,128)),
                    transforms.ToTensor()
                ])
myds = MyDataSet(dataset_path,no_transform)
print(len(myds))
tds_size = int(0.8*len(myds))
vds_size = len(myds)-tds_size
print(tds_size)
print(vds_size)

tds,vds = random_split(myds,[tds_size,vds_size])


tdl = DataLoader(tds,batch_size=32,shuffle=True)
vdl = DataLoader(vds,batch_size=32,shuffle=True)
# Out:
# 2137
# 1709
# 428

# %%
img , lbl = myds[1600]
timg, tlbl = tds[1600]
vimg, vlbl = vds[400]

fig, ax = plt.subplots(1, 3, figsize=(12,4))

ax[0].imshow(img.permute(1,2,0))
ax[0].set_title(lbl)

ax[1].imshow(timg.permute(1,2,0))
ax[1].set_title(tlbl)

ax[2].imshow(vimg.permute(1,2,0))
ax[2].set_title(vlbl)
# Out:
# Text(0.5, 1.0, '4')

# %%
class myModel(nn.Module):
  def __init__(self,p_dropout=0.0):
    super().__init__()
    self.conv1 = nn.Conv2d(3,16,kernel_size=3,padding=1)
    self.conv2 = nn.Conv2d(16,32,kernel_size=3,padding=1)
    self.conv3 = nn.Conv2d(32,64,kernel_size=3,padding=1)
    self.pool = nn.MaxPool2d(2)
    self.relu = nn.ReLU()
    self.flatten = nn.Flatten()
    self.fc1 = nn.Linear(64*16*16, 128)
    self.dropout = nn.Dropout(p_dropout)
    self.fc2 = nn.Linear(128, 7)

  def forward(self,x):
    x = self.pool(self.relu(self.conv1(x)))
    x = self.pool(self.relu(self.conv2(x)))
    x = self.pool(self.relu(self.conv3(x)))
    x = self.flatten(x)
    x = self.relu(self.fc1(x))
    x = self.dropout(x)
    x = self.fc2(x)
    return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = myModel(p_dropout=0.0).to(device)
print(device)
# Out:
# cuda

# %%
def train(model, train_ld, val_ld, epochs, lr=0.0001):
    loss_func = nn.CrossEntropyLoss()
    opt = optim.Adam(model.parameters(), lr=lr)

    history = {"train_loss": [],"val_loss": [],"train_acc": [],"val_acc": []}

    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        for img, lbl in train_ld:
            img, lbl = img.to(device), lbl.to(device)

            opt.zero_grad()
            prediction = model(img)
            loss = loss_func(prediction, lbl)
            loss.backward()
            opt.step()

            running_loss += loss.item() * img.size(0)
            correct += (prediction.argmax(1) == lbl).sum().item()
            total += lbl.size(0)

        train_loss = running_loss / total
        train_acc = correct / total

        model.eval()
        running_loss, correct, total = 0.0, 0, 0

        with torch.no_grad():
            for imgs, labels in val_ld:
                imgs, labels = imgs.to(device), labels.to(device)

                outputs = model(imgs)
                loss = loss_func(outputs, labels)

                running_loss += loss.item() * imgs.size(0)
                correct += (outputs.argmax(1) == labels).sum().item()
                total += labels.size(0)

        val_loss = running_loss / total
        val_acc = correct / total

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        print(
            f"Epoch {epoch+1:2d}/{epochs} | "
            f"train_loss={train_loss:.3f} train_acc={train_acc:.3f} | "
            f"val_loss={val_loss:.3f} val_acc={val_acc:.3f}"
        )

    return history

# %%
history_plain = train(model, tdl, vdl, epochs=50)
# Out:
# Epoch  1/50 | train_loss=1.845 train_acc=0.273 | val_loss=1.799 val_acc=0.250
# Epoch  2/50 | train_loss=1.765 train_acc=0.298 | val_loss=1.721 val_acc=0.318
# Epoch  3/50 | train_loss=1.674 train_acc=0.339 | val_loss=1.626 val_acc=0.360
# Epoch  4/50 | train_loss=1.587 train_acc=0.381 | val_loss=1.563 val_acc=0.341
# Epoch  5/50 | train_loss=1.504 train_acc=0.417 | val_loss=1.469 val_acc=0.414
# Epoch  6/50 | train_loss=1.425 train_acc=0.445 | val_loss=1.393 val_acc=0.458
# Epoch  7/50 | train_loss=1.351 train_acc=0.476 | val_loss=1.344 val_acc=0.470
# Epoch  8/50 | train_loss=1.278 train_acc=0.504 | val_loss=1.267 val_acc=0.519
# Epoch  9/50 | train_loss=1.221 train_acc=0.530 | val_loss=1.249 val_acc=0.528
# Epoch 10/50 | train_loss=1.150 train_acc=0.577 | val_loss=1.196 val_acc=0.547
# Epoch 11/50 | train_loss=1.102 train_acc=0.592 | val_loss=1.139 val_acc=0.558
# Epoch 12/50 | train_loss=1.040 train_acc=0.611 | val_loss=1.141 val_acc=0.575
# Epoch 13/50 | train_loss=1.012 train_acc=0.623 | val_loss=1.083 val_acc=0.565
# Epoch 14/50 | train_loss=0.959 train_acc=0.647 | val_loss=1.126 val_acc=0.561
# Epoch 15/50 | train_loss=0.943 train_acc=0.651 | val_loss=1.028 val_acc=0.600
# Epoch 16/50 | train_loss=0.915 train_acc=0.664 | val_loss=1.110 val_acc=0.558
# Epoch 17/50 | train_loss=0.875 train_acc=0.682 | val_loss=0.987 val_acc=0.596
# Epoch 18/50 | train_loss=0.846 train_acc=0.689 | val_loss=1.026 val_acc=0.596
# Epoch 19/50 | train_loss=0.808 train_acc=0.703 | val_loss=0.988 val_acc=0.624
# Epoch 20/50 | train_loss=0.820 train_acc=0.699 | val_loss=0.993 val_acc=0.614
# Epoch 21/50 | train_loss=0.759 train_acc=0.720 | val_loss=0.976 val_acc=0.610
# Epoch 22/50 | train_loss=0.729 train_acc=0.737 | val_loss=0.957 val_acc=0.617
# Epoch 23/50 | train_loss=0.702 train_acc=0.751 | val_loss=0.947 val_acc=0.640
# Epoch 24/50 | train_loss=0.697 train_acc=0.743 | val_loss=1.298 val_acc=0.512
# Epoch 25/50 | train_loss=0.703 train_acc=0.747 | val_loss=0.951 val_acc=0.621
# Epoch 26/50 | train_loss=0.655 train_acc=0.767 | val_loss=0.944 val_acc=0.619
# Epoch 27/50 | train_loss=0.618 train_acc=0.781 | val_loss=0.931 val_acc=0.633
# Epoch 28/50 | train_loss=0.605 train_acc=0.788 | val_loss=0.923 val_acc=0.621
# Epoch 29/50 | train_loss=0.605 train_acc=0.789 | val_loss=0.926 val_acc=0.636
# Epoch 30/50 | train_loss=0.570 train_acc=0.798 | val_loss=0.918 val_acc=0.617
# Epoch 31/50 | train_loss=0.544 train_acc=0.804 | val_loss=0.936 val_acc=0.636
# Epoch 32/50 | train_loss=0.544 train_acc=0.807 | val_loss=0.954 val_acc=0.626
# Epoch 33/50 | train_loss=0.515 train_acc=0.830 | val_loss=0.916 val_acc=0.636
# Epoch 34/50 | train_loss=0.485 train_acc=0.843 | val_loss=0.927 val_acc=0.617
# Epoch 35/50 | train_loss=0.482 train_acc=0.844 | val_loss=0.922 val_acc=0.638
# Epoch 36/50 | train_loss=0.456 train_acc=0.853 | val_loss=1.001 val_acc=0.612
# Epoch 37/50 | train_loss=0.453 train_acc=0.845 | val_loss=0.925 val_acc=0.633
# Epoch 38/50 | train_loss=0.438 train_acc=0.857 | val_loss=0.986 val_acc=0.617
# Epoch 39/50 | train_loss=0.407 train_acc=0.874 | val_loss=0.933 val_acc=0.624
# Epoch 40/50 | train_loss=0.400 train_acc=0.874 | val_loss=0.949 val_acc=0.619
# Epoch 41/50 | train_loss=0.372 train_acc=0.881 | val_loss=0.940 val_acc=0.633
# Epoch 42/50 | train_loss=0.365 train_acc=0.892 | val_loss=0.942 val_acc=0.631
# Epoch 43/50 | train_loss=0.361 train_acc=0.891 | val_loss=0.948 val_acc=0.659
# Epoch 44/50 | train_loss=0.340 train_acc=0.905 | val_loss=0.944 val_acc=0.629
# Epoch 45/50 | train_loss=0.318 train_acc=0.916 | val_loss=0.946 val_acc=0.629
# Epoch 46/50 | train_loss=0.320 train_acc=0.899 | val_loss=0.933 val_acc=0.640
# Epoch 47/50 | train_loss=0.311 train_acc=0.910 | val_loss=0.955 val_acc=0.640
# Epoch 48/50 | train_loss=0.290 train_acc=0.920 | val_loss=1.020 val_acc=0.614
# Epoch 49/50 | train_loss=0.309 train_acc=0.904 | val_loss=0.966 val_acc=0.657
# Epoch 50/50 | train_loss=0.271 train_acc=0.929 | val_loss=0.959 val_acc=0.643

# %%
def plot_history(history, title=""):
    epochs = range(1, len(history["train_loss"]) + 1)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    ax1.plot(epochs, history["train_loss"], "o-", label="train")
    ax1.plot(epochs, history["val_loss"],   "o-", label="validation")
    ax1.set_title("Loss (lower = better)")
    ax1.set_xlabel("epoch"); ax1.set_ylabel("loss"); ax1.legend(); ax1.grid(True)

    ax2.plot(epochs, history["train_acc"], "o-", label="train")
    ax2.plot(epochs, history["val_acc"],   "o-", label="validation")
    ax2.set_title("Accuracy (higher = better)")
    ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy"); ax2.legend(); ax2.grid(True)

    fig.suptitle(title)
    plt.tight_layout()
    plt.show()

plot_history(history_plain, "Without augmentation")

# %%
from torch.utils.data import random_split, Subset

normalize = transforms.Normalize(
    mean=[0.485, 0.456, 0.406],
    std=[0.229, 0.224, 0.225]
)

train_transform = transforms.Compose([
    # slightly larger resize
    transforms.Resize((160, 160)),

    # random crop for better generalization
    transforms.RandomResizedCrop(
        128,
        scale=(0.80, 1.0),
        ratio=(0.90, 1.10)
    ),

    # natural orientation changes
    transforms.RandomHorizontalFlip(p=0.5),

    # small rotation only
    transforms.RandomRotation(8),

    # mild lighting variation
    transforms.ColorJitter(
        brightness=0.10,
        contrast=0.10,
        saturation=0.08,
        hue=0.015
    ),

    # occasional blur
    transforms.RandomApply([
        transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 1.0))
    ], p=0.08),

    transforms.ToTensor(),
    normalize,

    # helps reduce overfitting
    transforms.RandomErasing(
        p=0.20,
        scale=(0.02, 0.06),
        ratio=(0.3, 3.3),
        value='random'
    )
])

val_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),normalize
])

train_dataset = MyDataSet(dataset_path, train_transform)
val_dataset = MyDataSet(dataset_path, val_transform)

dataset_size = len(train_dataset)

train_size = int(0.8 * dataset_size)
val_size = dataset_size - train_size

train_subset, val_subset = random_split(
    range(dataset_size),
    [train_size, val_size]
)

_tds = Subset(train_dataset, train_subset.indices)
_vds = Subset(val_dataset, val_subset.indices)

_tdl = DataLoader(_tds, batch_size=32, shuffle=True)
_vdl = DataLoader(_vds, batch_size=32, shuffle=False)

# %%
img , lbl = myds[1600]
timg, tlbl = _tds[1600]
vimg, vlbl = _vds[400]

fig, ax = plt.subplots(1, 3, figsize=(12,4))

ax[0].imshow(img.permute(1,2,0))
ax[0].set_title(lbl)

ax[1].imshow(timg.permute(1,2,0))
ax[1].set_title(tlbl)

ax[2].imshow(vimg.permute(1,2,0))
ax[2].set_title(vlbl)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0322802..2.2489083].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8952821..2.4308496].
# Text(0.5, 1.0, '2')

# %%
_model = myModel(p_dropout=0.5).to(device)

_history = train(_model,_tdl,_vdl,epochs=50)
plot_history(_history,"With augmentation")
# Out:
# Epoch  1/50 | train_loss=1.817 train_acc=0.290 | val_loss=1.696 val_acc=0.320
# Epoch  2/50 | train_loss=1.593 train_acc=0.377 | val_loss=1.417 val_acc=0.456
# Epoch  3/50 | train_loss=1.386 train_acc=0.460 | val_loss=1.235 val_acc=0.540
# Epoch  4/50 | train_loss=1.255 train_acc=0.515 | val_loss=1.132 val_acc=0.549
# Epoch  5/50 | train_loss=1.207 train_acc=0.522 | val_loss=1.091 val_acc=0.570
# Epoch  6/50 | train_loss=1.145 train_acc=0.562 | val_loss=1.057 val_acc=0.579
# Epoch  7/50 | train_loss=1.088 train_acc=0.579 | val_loss=0.980 val_acc=0.614
# Epoch  8/50 | train_loss=1.071 train_acc=0.586 | val_loss=0.961 val_acc=0.652
# Epoch  9/50 | train_loss=1.028 train_acc=0.598 | val_loss=0.939 val_acc=0.621
# Epoch 10/50 | train_loss=1.015 train_acc=0.594 | val_loss=0.905 val_acc=0.664
# Epoch 11/50 | train_loss=0.973 train_acc=0.635 | val_loss=0.893 val_acc=0.654
# Epoch 12/50 | train_loss=0.944 train_acc=0.642 | val_loss=0.871 val_acc=0.643
# Epoch 13/50 | train_loss=0.950 train_acc=0.645 | val_loss=0.885 val_acc=0.659
# Epoch 14/50 | train_loss=0.887 train_acc=0.669 | val_loss=0.845 val_acc=0.668
# Epoch 15/50 | train_loss=0.906 train_acc=0.655 | val_loss=0.843 val_acc=0.682
# Epoch 16/50 | train_loss=0.896 train_acc=0.650 | val_loss=0.806 val_acc=0.687
# Epoch 17/50 | train_loss=0.869 train_acc=0.678 | val_loss=0.793 val_acc=0.715
# Epoch 18/50 | train_loss=0.854 train_acc=0.675 | val_loss=0.782 val_acc=0.717
# Epoch 19/50 | train_loss=0.833 train_acc=0.679 | val_loss=0.746 val_acc=0.699
# Epoch 20/50 | train_loss=0.835 train_acc=0.690 | val_loss=0.753 val_acc=0.736
# Epoch 21/50 | train_loss=0.822 train_acc=0.680 | val_loss=0.739 val_acc=0.715
# Epoch 22/50 | train_loss=0.788 train_acc=0.706 | val_loss=0.799 val_acc=0.710
# Epoch 23/50 | train_loss=0.823 train_acc=0.691 | val_loss=0.741 val_acc=0.731
# Epoch 24/50 | train_loss=0.759 train_acc=0.711 | val_loss=0.724 val_acc=0.731
# Epoch 25/50 | train_loss=0.765 train_acc=0.701 | val_loss=0.710 val_acc=0.734
# Epoch 26/50 | train_loss=0.755 train_acc=0.693 | val_loss=0.728 val_acc=0.729
# Epoch 27/50 | train_loss=0.752 train_acc=0.706 | val_loss=0.692 val_acc=0.750
# Epoch 28/50 | train_loss=0.762 train_acc=0.713 | val_loss=0.721 val_acc=0.731
# Epoch 29/50 | train_loss=0.743 train_acc=0.724 | val_loss=0.682 val_acc=0.729
# Epoch 30/50 | train_loss=0.738 train_acc=0.707 | val_loss=0.691 val_acc=0.759
# Epoch 31/50 | train_loss=0.731 train_acc=0.725 | val_loss=0.712 val_acc=0.722
# Epoch 32/50 | train_loss=0.725 train_acc=0.717 | val_loss=0.671 val_acc=0.757
# Epoch 33/50 | train_loss=0.707 train_acc=0.733 | val_loss=0.702 val_acc=0.738
# Epoch 34/50 | train_loss=0.696 train_acc=0.749 | val_loss=0.656 val_acc=0.755
# Epoch 35/50 | train_loss=0.671 train_acc=0.743 | val_loss=0.656 val_acc=0.755
# Epoch 36/50 | train_loss=0.675 train_acc=0.755 | val_loss=0.677 val_acc=0.736
# Epoch 37/50 | train_loss=0.679 train_acc=0.759 | val_loss=0.635 val_acc=0.755
# Epoch 38/50 | train_loss=0.662 train_acc=0.734 | val_loss=0.630 val_acc=0.769
# Epoch 39/50 | train_loss=0.636 train_acc=0.762 | val_loss=0.625 val_acc=0.771
# Epoch 40/50 | train_loss=0.662 train_acc=0.748 | val_loss=0.746 val_acc=0.736
# Epoch 41/50 | train_loss=0.687 train_acc=0.750 | val_loss=0.628 val_acc=0.778
# Epoch 42/50 | train_loss=0.640 train_acc=0.750 | val_loss=0.665 val_acc=0.741
# Epoch 43/50 | train_loss=0.626 train_acc=0.761 | val_loss=0.635 val_acc=0.769
# Epoch 44/50 | train_loss=0.598 train_acc=0.771 | val_loss=0.613 val_acc=0.769
# Epoch 45/50 | train_loss=0.638 train_acc=0.750 | val_loss=0.611 val_acc=0.750
# Epoch 46/50 | train_loss=0.616 train_acc=0.760 | val_loss=0.658 val_acc=0.741
# Epoch 47/50 | train_loss=0.629 train_acc=0.766 | val_loss=0.620 val_acc=0.750
# Epoch 48/50 | train_loss=0.608 train_acc=0.768 | val_loss=0.619 val_acc=0.766
# Epoch 49/50 | train_loss=0.585 train_acc=0.783 | val_loss=0.632 val_acc=0.748
# Epoch 50/50 | train_loss=0.596 train_acc=0.769 | val_loss=0.632 val_acc=0.755

# %%
plt.figure(figsize=(7, 5))
plt.plot(history_plain["val_acc"], "o-", label="Round 1: no augmentation")
plt.plot(_history["val_acc"],   "o-", label="Round 2: augmentation")
plt.title("Validation accuracy — before vs after")
plt.xlabel("epoch"); plt.ylabel("validation accuracy")
plt.legend(); plt.grid(True)
plt.show()

print(f"Best val acc  (Round 1): {max(history_plain['val_acc']):.3f}")
print(f"Best val acc  (Round 2): {max(_history['val_acc']):.3f}")
# Out:
# Best val acc  (Round 1): 0.659
# Best val acc  (Round 2): 0.778

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import torch

# trained without augmentation
model_unaug = model

# trained with augmentation
model_aug = _model

def get_predictions(model, loader):
    model.eval()
    preds = []
    targets = []

    with torch.no_grad():
        for imgs, labels in loader:
            imgs = imgs.to(device)
            labels = labels.to(device)

            outputs = model(imgs)
            preds.extend(outputs.argmax(dim=1).cpu().numpy())
            targets.extend(labels.cpu().numpy())

    return targets, preds


class_names = [
    "Bacterial Blight",
    "Curl Virus",
    "Healthy Leaf",
    "Herbicide Growth Damage",
    "Leaf Hopper Jassids",
    "Leaf Redding",
    "Leaf Variegation"
]

# Predictions
y_true_unaug, y_pred_unaug = get_predictions(model_unaug, _vdl)
y_true_aug, y_pred_aug = get_predictions(model_aug, _vdl)

# Confusion matrices
cm_unaug = confusion_matrix(y_true_unaug, y_pred_unaug)
cm_aug = confusion_matrix(y_true_aug, y_pred_aug)

# Create one figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Unaugmented
disp1 = ConfusionMatrixDisplay(
    confusion_matrix=cm_unaug,
    display_labels=class_names
)
disp1.plot(ax=axes[0], cmap="Blues", values_format="d", colorbar=False)
axes[0].set_title("Without Augmentation")
axes[0].tick_params(axis='x', rotation=45)

# Augmented
disp2 = ConfusionMatrixDisplay(
    confusion_matrix=cm_aug,
    display_labels=class_names
)
disp2.plot(ax=axes[1], cmap="Greens", values_format="d", colorbar=False)
axes[1].set_title("With Augmentation")
axes[1].tick_params(axis='x', rotation=45)

plt.suptitle("Confusion Matrix Comparison", fontsize=16)
plt.tight_layout()
plt.show()

print("===== WITHOUT AUGMENTATION =====")
print(classification_report(y_true_unaug, y_pred_unaug, target_names=class_names))

print("===== WITH AUGMENTATION =====")
print(classification_report(y_true_aug, y_pred_aug, target_names=class_names))
# Out:
# ===== WITHOUT AUGMENTATION =====
#                          precision    recall  f1-score   support
#
#        Bacterial Blight       0.00      0.00      0.00        55
#              Curl Virus       0.31      0.60      0.41        81
#            Healthy Leaf       1.00      0.12      0.22        48
# Herbicide Growth Damage       0.23      0.96      0.38        54
#     Leaf Hopper Jassids       1.00      0.06      0.12        47
#            Leaf Redding       0.87      0.28      0.42       118
#        Leaf Variegation       0.00      0.00      0.00        25
#
#                accuracy                           0.33       428
#               macro avg       0.49      0.29      0.22       428
#            weighted avg       0.55      0.33      0.28       428
#
# ===== WITH AUGMENTATION =====
#                          precision    recall  f1-score   support
#
#        Bacterial Blight       0.62      0.58      0.60        55
#              Curl Virus       0.72      0.79      0.75        81
#            Healthy Leaf       0.66      0.52      0.58        48
# Herbicide Growth Damage       0.82      0.94      0.88        54
#     Leaf Hopper Jassids       0.67      0.62      0.64        47
#            Leaf Redding       0.87      0.86      0.86       118
#        Leaf Variegation       0.75      0.84      0.79        25
#
#                accuracy                           0.75       428
#               macro avg       0.73      0.74      0.73       428
#            weighted avg       0.75      0.75      0.75       428
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from torchsummary import summary
model.eval() 
summary(model, input_size=(3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 128]             448
#               ReLU-2         [-1, 16, 128, 128]               0
#          MaxPool2d-3           [-1, 16, 64, 64]               0
#             Conv2d-4           [-1, 32, 64, 64]           4,640
#               ReLU-5           [-1, 32, 64, 64]               0
#          MaxPool2d-6           [-1, 32, 32, 32]               0
#             Conv2d-7           [-1, 64, 32, 32]          18,496
#               ReLU-8           [-1, 64, 32, 32]               0
#          MaxPool2d-9           [-1, 64, 16, 16]               0
#           Flatten-10                [-1, 16384]               0
#            Linear-11                  [-1, 128]       2,097,280
#              ReLU-12                  [-1, 128]               0
#           Dropout-13                  [-1, 128]               0
#            Linear-14                    [-1, 7]             903
# ================================================================
# Total params: 2,121,767
# Trainable params: 2,121,767
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 8.00
# Params size (MB): 8.09
# Estimated Total Size (MB): 16.28
# ----------------------------------------------------------------
